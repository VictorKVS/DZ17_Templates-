# %% [markdown]
# ### Домашнее задание: Создание шаблонов для интернет-магазина
#
# Тема #17. Templates. Работа с шаблонами
#
# Описание темы:
# Цель:
#
# научить вас работе с шаблонами в Django для создания динамических веб-страниц.
# Вы освоите основные принципы работы с шаблонами, включая их создание, подключение и настройку.
# Особое внимание будет уделено использованию шаблонных тегов и фильтров для отображения данных, а также принципам наследования шаблонов для повторного использования кода.
# Вы освоите процесс рендеринга шаблонов с помощью контекста и научитесь работать с динамическими данными, передаваемыми из представлений. Кроме того, будет рассмотрено, как использовать статические и медиа-файлы для стилизации страниц, а также как обрабатывать формы и выполнять CSRF-защиту. Эти навыки позволят вам создать полноценное веб-приложение, которое будет иметь современный интерфейс и функционал.
# Результат освоения темы:
#
# вы сможете создавать и использовать шаблоны в ваших Django-приложениях.
# Вы научитесь рендерить динамические страницы, передавать данные в шаблоны и использовать шаблонные теги и фильтры для форматирования информации.
# Также вы сможете реализовать наследование шаблонов для упрощения разработки и создания общего дизайна. Полученные навыки помогут вам создать более интерактивные и привлекательные веб-приложения с использованием Django.
# Место в курсе:
#
# Изучение работы с шаблонами является важным этапом в освоении Django и веб-разработки в целом.
# Навыки, полученные на уроке, станут основой для создания более сложных приложений, таких как интернет-магазины, блоги или социальные платформы.
# Понимание работы с шаблонами и динамическими данными подготовит вас к работе с API и фронтенд-фреймворками, а также позволит вам освоить более продвинутые темы, такие как асинхронная обработка запросов и тестирование интерфейсов.
# Материалы по теме: https://disk.yandex.ru/d/YVKyvZIfnSQDoQ
#
# Запись от 01.10.2024 г.(Михал Деркунов):
#
# Яндекс Диск I Templates. Работа с шаблонами
#
# VK I Templates. Работа с шаблонами
#
# YouTube I Templates. Работа с шаблонами
#
# Задание Lite
# Задание Lite
# Макс 10 баллов
# Это проверка базовых знаний пройденного вами материала. Задания здесь, как правило, направлены на закрепление навыков и использование их на практике. Справившись с этим уровнем, вам по силам станут задачи, по типу рассмотренных на уроке. Большинство реальных проектов можно решить, правильно комбинируя эти навыки. Это задание необходимо выполнить для получения документов о прохождении курса (только если Вы не планируете выполнять PRO или ULTRA PRO уровни, тогда Lite необязательно). Дежурные кураторы ответят вам на все вопросы, которые касаются данного уровня ДЗ.
# Задание Lite: https://disk.yandex.ru/d/Kjjq0yluuHHPDw
#
# *Проверка задания осуществляется куратором. Результат проверки вы получите в течение 3 дней.
# Если задание куратор не примет, оно будет отправлено на доработку.
# Для того, чтобы задание было зачтено, необходимо получить 8 балов из 10.
#
# #### Задача:
#
# Вы будете разрабатывать шаблоны для простого интернет-магазина, который будет отображать список товаров и детали каждого товара. Используйте знания о шаблонах, фильтрах и наследовании.
#
# #### Этапы выполнения:
#
# 1. **Создание модели товара**:
#    - Создайте модель `Product` в `models.py`, которая будет содержать следующие поля:
#      - `name` (название товара, CharField)
#      - `description` (описание товара, TextField)
#      - `price` (цена товара, DecimalField)
#      - `image` (изображение товара, ImageField)
#      - `created_at` (дата создания, DateTimeField)
#
# 2. **Создание представлений**:
#    - Создайте два представления:
#      - `product_list`: отображает список всех товаров. Передайте контекст с информацией о товарах в шаблон.
#      - `product_detail`: отображает детальную информацию о конкретном товаре. Используйте `product_id`, чтобы получить нужный товар из базы данных.
#
# 3. **Создание шаблонов**:
#    - Создайте базовый шаблон `base.html`, который будет содержать общий стиль (например, хэдер и футер).
#    - Создайте шаблон `product_list.html`, который будет наследоваться от `base.html` и отображать список товаров. Каждый товар должен содержать название, цену и изображение. Используйте фильтры для форматирования цены (например, отображать ее с двумя знаками после запятой).
#    - Создайте шаблон `product_detail.html`, который также будет наследоваться от `base.html` и отображать детальную информацию о товаре, включая название, описание, цену и изображение.
#
# 4. **Статические файлы**:
#    - Используйте статические файлы для стилизации ваших шаблонов (например, добавьте CSS для улучшения внешнего вида).
#
# 5. **Рендеринг данных**:
#    - Убедитесь, что все данные корректно рендерятся в шаблонах. Используйте конструкции `{% for %}`, `{% if %}` и фильтры.
#
# #### Дополнительные требования:
#
# - **Документация**: Добавьте комментарии в код, объясняющие основные моменты реализации.
# - **Обработка ошибок**: Добавьте обработку случая, когда не найден товар, на странице `product_detail.html`.
# - **Структура проекта**: Поддерживайте организованную структуру каталогов для шаблонов, используя стандартные практики.
#
# #### Оценка:
#
# - **Полнота выполнения задания** (50%)
# - **Качество и читаемость кода** (30%)
# - **Эстетика и функциональность интерфейса** (20%)
